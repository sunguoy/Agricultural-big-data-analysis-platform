# %%
import pandas as pd

data = pd.read_csv("./data.csv")

# %%
# for i in range(2013,2020):
#     print(data[data["county_year"] == f"长丰_{i}"]["18周平均气压均值"].values)
for i in set(','.join(data["county_year"].values.tolist()).replace("_", "").replace("2013", "").replace("2014", "").replace(
    "2015", "").replace("2016", "").replace("2017", "").replace("2018", "").replace("2019", "").split(",")):
    print(i)
# Out:
# 巢湖
# 怀宁
# 天长
# 潜山
# 宿松
# 芜湖
# 五河
# 全椒
# 太湖
# 望江
# 凤台
# 利辛
# 桐城
# 青阳
# 凤阳
# 宁国
# 无为
# 田家庵
# 广德
# 当涂
# 长丰
# 肥西
# 歙县
# 舒城
# 祁门
# 枞阳
# 东芝
# 阜南
# 含山
# 合肥
# 明光
# 南宁
# 肥东
# 金寨
# 霍邱
# 颍上
# 怀远

# %%
','.join(data.columns.sort_values().tolist()).replace("")
# Out:
# '18周平均气压均值,18周平均气温均值,18周平均水气压均值,18周平均风速均值,18周总日照时数,18周总降水量,18周日照时数均值,18周日降水量均值,18周最低气压,18周最低气压均值,18周最低气温,18周最低气温均值,18周最大风速,18周最大风速均值,18周最小相对湿度,18周最小相对湿度均值,18周最高气压,18周最高气压均值,18周最高气温,18周最高气温均值,18周相对湿度均值,19周平均气压均值,19周平均气温均值,19周平均水气压均值,19周平均风速均值,19周总日照时数,19周总降水量,19周日照时数均值,19周日降水量均值,19周最低气压,19周最低气压均值,19周最低气温,19周最低气温均值,19周最大风速,19周最大风速均值,19周最小相对湿度,19周最小相对湿度均值,19周最高气压,19周最高气压均值,19周最高气温,19周最高气温均值,19周相对湿度均值,20周平均气压均值,20周平均气温均值,20周平均水气压均值,20周平均风速均值,20周总日照时数,20周总降水量,20周日照时数均值,20周日降水量均值,20周最低气压,20周最低气压均值,20周最低气温,20周最低气温均值,20周最大风速,20周最大风速均值,20周最小相对湿度,20周最小相对湿度均值,20周最高气压,20周最高气压均值,20周最高气温,20周最高气温均值,20周相对湿度均值,21周平均气压均值,21周平均气温均值,21周平均水气压均值,21周平均风速均值,21周总日照时数,21周总降水量,21周日照时数均值,21周日降水量均值,21周最低气压,21周最低气压均值,21周最低气温,21周最低气温均值,21周最大风速,21周最大风速均值,21周最小相对湿度,21周最小相对湿度均值,21周最高气压,21周最高气压均值,21周最高气温,21周最高气温均值,21周相对湿度均值,22周平均气压均值,22周平均气温均值,22周平均水气压均值,22周平均风速均值,22周总日照时数,22周总降水量,22周日照时数均值,22周日降水量均值,22周最低气压,22周最低气压均值,22周最低气温,22周最低气温均值,22周最大风速,22周最大风速均值,22周最小相对湿度,22周最小相对湿度均值,22周最高气压,22周最高气压均值,22周最高气温,22周最高气温均值,22周相对湿度
# ...
